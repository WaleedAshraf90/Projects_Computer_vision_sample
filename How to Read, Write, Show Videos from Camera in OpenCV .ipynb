# %%
import numpy as np
import cv2


cap=cv2.VideoCapture(0)# انا بقول هسجل فيديو من كامير الجهاز او اننى اعمل واحد ةاحط اسم الفيديو اللى انا عايزة
fourcc = cv2.VideoWriter_fourcc(*'XVID')#بتظبط الفيدو


out=cv2.VideoWriter("out1222.avi",fourcc,20.2,(640,480))#fourcc  20 فريم حاجة بتظبط الفيدو اللى هو الكفاءة

# %%
print(cap.isOpened())# check is vodeo
while (cap.isOpened()): # or While True carera open
    ret,frame=cap.read() #القراه هترجعل فريم
    if ret== True: # هيسجل الارتفاع والعرض
        print(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
        print(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    
        out.write(frame)
    
    
        gray=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY) #حولت الفديو الى جرى
        cv2.imshow("frame",gray)
        
    else :
        out == ord('s') #if order is s save the image   لو عايز احفظ الصورة ادوس   s
        cv2.imwrite('applecopy.av1', img)
    if cv2.waitKey(1) == ord('q'): # متخصص فى الغاء الصورة
          break

    
cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# True
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# ...
